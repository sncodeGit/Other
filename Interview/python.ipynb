# %% [markdown]
# <center style="font-size: 26px"> <b>Проверка уровня знаний Python</b></center>

# %% [markdown]
# ### Проверка построена следующим образом:
#
# - К каждому блоку приложены практические задания по теме блока
# - К каждому практическому заданию приложен либо рабочий файл, либо дано вводное условие
# - Для успешного прохождения проверки требуется правильно ответить на 10/15 вопросов
# - Корректным ответом на вопрос считается любой работоспособный код, позволяющий достичь корректного результата (и использующий проверяемый синтаксис, если это указано в условии задания)

# %% [markdown]
# <center style="background-color: #23B04A; color: white; font-size: 16px"><b>NumPy</b></center>

# %% [markdown]
# `Numpy` - это библиотека Python для вычислительно эффективных операций с многомерными массивами, предназначенная в основном для научных вычислений.

# %% [markdown]
# ### Технический код:
# Данная часть нужна исключительно для корректной работы данной тетради. Исполните блок (Shift + Enter), не вдаваясь в суть написанного.

# %%
# обеспечиваем совместимость с Python 2 и 3
from __future__ import (absolute_import, division, print_function, unicode_literals)

# отключаем предупреждения дистрибутива Anaconda
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### Практические задания:

# %%
# Импортируем библиотеки NumPy и Pandas
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1. Создание массивов
# Создайте и перемножьте одномерный и двумерный массивы при помощи библиотеки NumPy

# %%
first_dim = 10 # Количество элементов в итоговом массиве 
second_dim = 5 # Количество элементов в изначальном массиве
# In: twodim_arr.shape 
# Out: (first_dim_, second_dim)
twodim_arr = np.random.sample((first_dim, second_dim)) 
onedim_arr = np.random.sample(second_dim) 
result = np.dot(twodim_arr, onedim_arr)
result
# Out:
# array([1.47122802, 1.36267933, 1.35280075, 1.38747178, 1.29590897,
#        1.22825565, 1.14951033, 1.72325746, 1.40380956, 1.3174231 ])

# %% [markdown]
# #### 2. Методы создания массивов
# Создайте один и тот же массив 3-мя разными способами при помощи библиотеки NumPy

# %%
print(np.arange(1, 4))
print(np.array([1, 2, 3])) # Из list
print(np.fromiter(iter([1, 2, 3]), dtype = int)) # Из итерируемого типа
# Out:
# [1 2 3]
# [1 2 3]
# [1 2 3]

# %% [markdown]
# #### 3. Индексирование массивов
#
# Напишите код, производящий указанные в комментариях операции с массивами

# %%
a = np.diag(np.arange(3))  # Выделите значение = 1
a[1,1] 
# Или
a[a == 1] # Будет выбран массив элементов со значением 1 (In: a[a == 1] | Out: [1])

b = np.random.rand(5, 5)  # Выделите первую строку
b[0]

c = np.arange(10) # Присвойте значение = 25 элементам массива с 3 по 6 включительно
c[2:6] = 25 # В случае индексации элементов массива с 1

# %% [markdown]
# #### 4. Индексирование масками
#
# Выберите из предоставленного массива значения, делящиеся на 3 без остатка, и присвойте им значение = 10

# %%
np.random.seed(3)
a = np.random.random_integers(0, 20, 15)

print(a)
a[a % 3 == 0] = 10
# Out:
# [10  3  8  0 19 10 11  9 10  6  0 20 12  7 14]

# %% [markdown]
# #### 5. Меры центральной тенденции и меры вариации
#
# Напишите код, находящий указанные в комментариях значения

# %%
a = np.linspace(0, 20, 5)  # Найти среднее арифметическое массива
print(np.mean(a))

b = np.linspace(0, 30, 10)  # Найти медианное значение массива
print(np.median(b))

c = np.linspace(0, 10, 10)  # Найти кумулятивную сумму элементов массива
print(np.cumsum(c))
# Out:
# 10.0
# 15.0
# [ 0.          1.11111111  3.33333333  6.66666667 11.11111111 16.66666667
#  23.33333333 31.11111111 40.         50.        ]

# %% [markdown]
# <center style="background-color: #23B04A; color: white; font-size: 16px"><b>Pandas</b></center>

# %% [markdown]
# `Pandas` - это библиотека Python, предоставляющая широкие возможности для анализа данных. С ее помощью очень удобно загружать, обрабатывать и анализировать табличные данные с помощью SQL-подобных запросов. В связке с библиотеками Matplotlib и Seaborn появляется возможность удобного визуального анализа табличных данных (данные библиотеки включены в следующий уровень assessment'а).

# %% [markdown]
# #### 6. Чтение и первичная информация о файле
# Выведите первые 15 значений (строк) датафрейма, полученного из файла 'adult.data'

# %%
# читаем файл и загоняем в датафрейм
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header=None)
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 
'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'salary']

# %%
df.head(15)
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# 13   32            Private  205019     Assoc-acdm             12
# 14   40            Private  121772      Assoc-voc             11
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 2                 Divorced   Handlers-cleaners   Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 4       Married-civ-spouse      Prof-specialty            Wife
# 5       Married-civ-spouse     Exec-managerial            Wife
# 6    Married-spouse-absent       Other-service   Not-in-family
# 7       Married-civ-spouse     Exec-managerial         Husband
# 8            Never-married      Prof-specialty   Not-in-family
# 9       Married-civ-spouse     Exec-managerial         Husband
# 10      Married-civ-spouse     Exec-managerial         Husband
# 11      Married-civ-spouse      Prof-specialty         Husband
# 12           Never-married        Adm-clerical       Own-child
# 13           Never-married               Sales   Not-in-family
# 14      Married-civ-spouse        Craft-repair         Husband
#
#                    race      sex  capital-gain  capital-loss  hours-per-week  \
# 0                 White     Male          2174             0              40
# 1                 White     Male             0             0              13
# 2                 White     Male             0             0              40
# 3                 Black     Male             0             0              40
# 4                 Black   Female             0             0              40
# 5                 White   Female             0             0              40
# 6                 Black   Female             0             0              16
# 7                 White     Male             0             0              45
# 8                 White   Female         14084             0              50
# 9                 White     Male          5178             0              40
# 10                Black     Male             0             0              80
# 11   Asian-Pac-Islander     Male             0             0              40
# 12                White   Female             0             0              30
# 13                Black     Male             0             0              50
# 14   Asian-Pac-Islander     Male             0             0              40
#
#     native-country  salary
# 0    United-States   <=50K
# 1    United-States   <=50K
# 2    United-States   <=50K
# 3    United-States   <=50K
# 4             Cuba   <=50K
# 5    United-States   <=50K
# 6          Jamaica   <=50K
# 7    United-States    >50K
# 8    United-States    >50K
# 9    United-States    >50K
# 10   United-States    >50K
# 11           India    >50K
# 12   United-States   <=50K
# 13   United-States   <=50K
# 14               ?    >50K

# %% [markdown]
# Каждая строка данного фрейма - это участник социологического опроса, проведённого в Америке

# %% [markdown]
# #### 7. Индексация с условием
# Вынесите в новый датафрейм с названием df_work мужчин (признак *sex*) старше 35 (признак *age*)

# %%
# Т.к. в df.sex содержатся строки с лишними пробелами, при сравнении со строкой 'Male' будем удалять их из строки
df_work = df[(df.sex.apply(lambda x: x.replace(' ', '')) == 'Male') & (df.age > 35)]
df_work

# %% [markdown]
# #### 8. Группировка и меры центральной тенденции
# Сгруппируйте всех опрошенных по уровню образования (признак *education*) и найдите среднее значение по каждому из числовых (type = int) столбцов в каждой из получившихся групп

# %%
df.groupby('education').mean()
# Out:
#                      age         fnlwgt  education-num  capital-gain  \
# education
#  10th          37.429796  196832.465166            6.0    404.574491
#  11th          32.355745  194928.077447            7.0    215.097872
#  12th          32.000000  199097.508083            8.0    284.087760
#  1st-4th       46.142857  239303.000000            2.0    125.875000
#  5th-6th       42.885886  232448.333333            3.0    176.021021
#  7th-8th       48.445820  188079.171827            4.0    233.939628
#  9th           41.060311  202485.066148            5.0    342.089494
#  Assoc-acdm    37.381443  193424.093721           12.0    640.399250
#  Assoc-voc     38.553546  181936.016643           11.0    715.051375
#  Bachelors     38.904949  188055.914846           13.0   1756.299533
#  Doctorate     47.702179  186698.760291           16.0   4770.145278
#  HS-grad       38.974479  189538.739739            9.0    576.800114
#  Masters       44.049913  179852.362739           14.0   2562.563552
#  Preschool     42.764706  235889.372549            1.0    898.392157
#  Prof-school   44.746528  185663.706597           15.0  10414.416667
#  Some-college  35.756275  188742.922370           10.0    598.824167
#
#                capital-loss  hours-per-week
# education
#  10th             56.845659       37.052519
#  11th             50.079149       33.925957
#  12th             32.337182       35.780600
#  1st-4th          48.327381       38.255952
#  5th-6th          68.252252       38.897898
#  7th-8th          65.668731       39.366873
#  9th              28.998054       38.044747
#  Assoc-acdm       93.418932       40.504217
#  Assoc-voc        72.754703       41.610709
#  Bachelors       118.350327       42.614006
#  Doctorate       262.845036       46.973366
#  HS-grad          70.466622       40.575374
#  Masters         166.719675       43.836332
#  Preschool        66.490196       36.647059
#  Prof-school     231.203125       47.425347
#  Some-college     71.637087       38.852284

# %% [markdown]
# #### 9. Объединения и слияния
# Объедините имеющийся датафрейм adult.data с прописанными ниже df_2 (новая колонка) и df_3 (новая строка), затем отсортируйте по признаку *age*

# %%
df_2 = pd.DataFrame({'random_column': np.random.rand(32561)})
df_3 = pd.DataFrame({'age': 40, 'workclass': 'Self-emp-not-inc', 'fnlwgt': 135415, 'education': 'Some-college', 'education-num': 10, 'marital-status': 'Married-civ-spouse', 'occupation': 'Other-service', 'relationship': 'Wife', 'race': 'White', 'sex': 'Female', 'capital-gain': 0, 'capital-loss': 0, 'hours-per-week': 5, 'native-country': 'United-States', 'salary': '<=50K'}, index=[32562])

df = df.merge(df_2, right_index = True, left_index = True)
df = df.merge(df_3, how = 'outer')
df = df.sort_values(by = 'age')
df
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 6895    17            Private  100828   Some-college             10
# 14907   17            Private  327127           11th              7
# 7788    17            Private  287160           11th              7
# 12919   17            Private   75333           10th              6
# 7764    17            Private  154398           11th              7
# 26800   17            Private  160758           10th              6
# 26814   17            Private  101626            9th              5
# 23178   17            Private  132636           11th              7
# 21557   17                  ?  241021           12th              8
# 7672    17                  ?  659273           11th              7
# 7653    17            Private  221129            9th              5
# 26874   17        Federal-gov   99893           11th              7
# 22965   17            Private   54257           11th              7
# 26905   17            Private  220562            9th              5
# 31774   17                  ?  256173           10th              6
# 19016   17            Private  198830           11th              7
# 26969   17            Private  108273           10th              6
# 26871   17            Private  238628           11th              7
# 14862   17       Self-emp-inc  413557            9th              5
# 7957    17            Private  186067           10th              6
# 31866   17            Private  214787           12th              8
# 8302    17            Private  342752           11th              7
# 804     17            Private  193830           11th              7
# 26423   17                  ?   67808           10th              6
# 14699   17                  ?  303317           11th              7
# 814     17            Private   32607           10th              6
# 22936   17                  ?  332666           10th              6
# 14731   17            Private   99462           11th              7
# 840     17            Private  198124           11th              7
# 8140    17            Private  111332           11th              7
# ...    ...                ...     ...            ...            ...
# 18845   90            Private  115306        Masters             14
# 6631    90            Private  313986           11th              7
# 6239    90   Self-emp-not-inc  155981      Bachelors             13
# 32368   90          Local-gov  214594        7th-8th              4
# 32278   90            Private  313749        HS-grad              9
# 22231   90            Private   52386      Bachelors             13
# 5373    90          Local-gov  227796        Masters             14
# 28469   90        Federal-gov  195433        HS-grad              9
# 15367   90            Private   90523        HS-grad              9
# 11524   90            Private   87285        HS-grad              9
# 12987   90            Private  250832           10th              6
# 18292   90            Private  311184      Bachelors             13
# 15903   90            Private   88991      Bachelors             13
# 24246   90                  ?  166343        1st-4th              2
# 12463   90                  ?  225063   Some-college             10
# 31032   90            Private   47929        HS-grad              9
# 20623   90            Private  206667        Masters             14
# 5409    90            Private   51744        Masters             14
# 1935    90            Private  221832      Bachelors             13
# 10221   90   Self-emp-not-inc  282095   Some-college             10
# 5275    90            Private  141758            9th              5
# 25311   90                  ?  175444        7th-8th              4
# 18738   90          Local-gov  153602        HS-grad              9
# 4111    90                  ?  256514      Bachelors             13
# 4072    90            Private  313986           11th              7
# 12008   90            Private   40388      Bachelors             13
# 2303    90            Private   52386   Some-college             10
# 2304    90            Private   52386   Some-college             10
# 10557   90            Private  175491        HS-grad              9
# 1040    90            Private  137018        HS-grad              9
#
#             marital-status          occupation     relationship  \
# 6895         Never-married        Adm-clerical        Own-child
# 14907        Never-married    Transport-moving        Own-child
# 7788         Never-married       Other-service        Own-child
# 12919        Never-married               Sales        Own-child
# 7764         Never-married       Other-service        Own-child
# 26800        Never-married               Sales   Other-relative
# 26814        Never-married   Machine-op-inspct        Own-child
# 23178        Never-married    Transport-moving        Own-child
# 21557        Never-married                   ?        Own-child
# 7672         Never-married                   ?        Own-child
# 7653    Married-civ-spouse       Other-service          Husband
# 26874        Never-married        Adm-clerical    Not-in-family
# 22965        Never-married        Adm-clerical        Own-child
# 26905        Never-married               Sales   Other-relative
# 31774        Never-married                   ?        Own-child
# 19016        Never-married        Adm-clerical   Other-relative
# 26969        Never-married               Sales        Own-child
# 26871        Never-married       Other-service        Own-child
# 14862        Never-married               Sales        Own-child
# 7957         Never-married        Tech-support        Own-child
# 31866        Never-married        Adm-clerical        Own-child
# 8302         Never-married   Handlers-cleaners        Own-child
# 804          Never-married               Sales        Own-child
# 26423        Never-married                   ?        Own-child
# 14699        Never-married                   ?        Own-child
# 814          Never-married     Farming-fishing        Own-child
# 22936        Never-married                   ?        Own-child
# 14731        Never-married       Other-service        Own-child
# 840          Never-married               Sales        Own-child
# 8140         Never-married               Sales        Own-child
# ...                    ...                 ...              ...
# 18845        Never-married     Exec-managerial        Own-child
# 6631    Married-civ-spouse        Craft-repair          Husband
# 6239    Married-civ-spouse      Prof-specialty          Husband
# 32368   Married-civ-spouse     Protective-serv          Husband
# 32278              Widowed        Adm-clerical        Unmarried
# 22231        Never-married      Prof-specialty    Not-in-family
# 5373    Married-civ-spouse     Exec-managerial          Husband
# 28469   Married-civ-spouse        Craft-repair          Husband
# 15367              Widowed    Transport-moving        Unmarried
# 11524        Never-married       Other-service        Own-child
# 12987   Married-civ-spouse     Exec-managerial          Husband
# 18292   Married-civ-spouse               Sales          Husband
# 15903   Married-civ-spouse     Exec-managerial             Wife
# 24246              Widowed                   ?    Not-in-family
# 12463        Never-married                   ?        Own-child
# 31032   Married-civ-spouse   Machine-op-inspct          Husband
# 20623   Married-civ-spouse      Prof-specialty             Wife
# 5409         Never-married     Exec-managerial    Not-in-family
# 1935    Married-civ-spouse     Exec-managerial          Husband
# 10221   Married-civ-spouse     Farming-fishing          Husband
# 5275         Never-married        Adm-clerical    Not-in-family
# 25311            Separated                   ?    Not-in-family
# 18738   Married-civ-spouse       Other-service          Husband
# 4111               Widowed                   ?   Other-relative
# 4072         Never-married   Handlers-cleaners        Own-child
# 12008        Never-married     Exec-managerial    Not-in-family
# 2303         Never-married       Other-service    Not-in-family
# 2304         Never-married       Other-service    Not-in-family
# 10557   Married-civ-spouse        Craft-repair          Husband
# 1040         Never-married       Other-service    Not-in-family
#
#                       race      sex  capital-gain  capital-loss  \
# 6895                 White     Male             0             0
# 14907                White     Male             0             0
# 7788                 White   Female             0             0
# 12919                Black   Female             0             0
# 7764                 Black     Male             0             0
# 26800                White     Male             0             0
# 26814                White     Male             0             0
# 23178                White   Female             0             0
# 21557                Other   Female             0             0
# 7672                 Black   Female             0             0
# 7653                 White     Male             0             0
# 26874                Black   Female             0          1602
# 22965                White   Female             0             0
# 26905                Other   Female             0             0
# 31774                White   Female             0             0
# 19016                White   Female             0             0
# 26969                White   Female             0             0
# 26871                White   Female             0             0
# 14862                White   Female             0             0
# 7957                 White     Male             0             0
# 31866                White   Female             0             0
# 8302                 White     Male             0             0
# 804                  White   Female             0             0
# 26423                White     Male             0             0
# 14699                White     Male             0             0
# 814                  White     Male             0             0
# 22936                White   Female             0             0
# 14731   Amer-Indian-Eskimo   Female             0             0
# 840                  White     Male             0             0
# 8140                 White   Female             0             0
# ...                    ...      ...           ...           ...
# 18845                White   Female             0             0
# 6631                 White     Male             0             0
# 6239                 White     Male         10566             0
# 32368                White     Male          2653             0
# 32278                White   Female             0             0
# 22231   Asian-Pac-Islander     Male             0             0
# 5373                 White     Male         20051             0
# 28469                White     Male             0             0
# 15367                White     Male             0             0
# 11524                White   Female             0             0
# 12987                White     Male             0             0
# 18292                White     Male             0             0
# 15903                White   Female             0             0
# 24246                Black   Female             0             0
# 12463   Asian-Pac-Islander     Male             0             0
# 31032                White     Male             0             0
# 20623                White   Female             0             0
# 5409                 Black     Male             0             0
# 1935                 White     Male             0             0
# 10221                White     Male             0             0
# 5275                 White   Female             0             0
# 25311                White   Female             0             0
# 18738                White     Male          6767             0
# 4111                 White   Female           991             0
# 4072                 White     Male             0             0
# 12008                White     Male             0             0
# 2303    Asian-Pac-Islander     Male             0             0
# 2304    Asian-Pac-Islander     Male             0             0
# 10557                White     Male          9386             0
# 1040                 White   Female             0             0
#
#        hours-per-week    native-country  salary  random_column
# 6895               20     United-States   <=50K       0.279927
# 14907              20     United-States   <=50K       0.770537
# 7788               15     United-States   <=50K       0.634875
# 12919              24     United-States   <=50K       0.842876
# 7764               16             Haiti   <=50K       0.674406
# 26800              30     United-States   <=50K       0.998907
# 26814              20     United-States   <=50K       0.952160
# 23178              16     United-States   <=50K       0.656573
# 21557              40     United-States   <=50K       0.999850
# 7672               40   Trinadad&Tobago   <=50K       0.085855
# 7653               40     United-States   <=50K       0.046003
# 26874              40     United-States   <=50K       0.998641
# 22965              20     United-States   <=50K       0.209581
# 26905              32            Mexico   <=50K       0.979976
# 31774              15     United-States   <=50K       0.629067
# 19016              10     United-States   <=50K       0.851806
# 26969              12     United-States   <=50K       0.777356
# 26871               5     United-States   <=50K       0.629979
# 14862              40     United-States   <=50K       0.301796
# 7957               10     United-States   <=50K       0.896886
# 31866              25     United-States   <=50K       0.346500
# 8302               20     United-States   <=50K       0.937506
# 804                20     United-States   <=50K       0.074454
# 26423              40     United-States   <=50K       0.260281
# 14699              40     United-States   <=50K       0.936721
# 814                20     United-States   <=50K       0.889616
# 22936               4     United-States   <=50K       0.060667
# 14731              20     United-States   <=50K       0.894025
# 840                20     United-States   <=50K       0.426899
# 8140               20     United-States   <=50K       0.632853
# ...               ...               ...     ...            ...
# 18845              40     United-States   <=50K       0.508330
# 6631               40     United-States   <=50K       0.950349
# 6239               50     United-States   <=50K       0.919583
# 32368              40     United-States   <=50K       0.681438
# 32278              25     United-States   <=50K       0.298558
# 22231              40     United-States   <=50K       0.498411
# 5373               60     United-States    >50K       0.953655
# 28469              30     United-States   <=50K       0.498398
# 15367              99     United-States   <=50K       0.662337
# 11524              24     United-States   <=50K       0.249119
# 12987              40     United-States   <=50K       0.138414
# 18292              20                 ?   <=50K       0.177786
# 15903              40           England    >50K       0.720498
# 24246              40     United-States   <=50K       0.908209
# 12463              10             South   <=50K       0.526599
# 31032              40     United-States   <=50K       0.624678
# 20623              40     United-States    >50K       0.256776
# 5409               50     United-States    >50K       0.022994
# 1935               45     United-States   <=50K       0.289285
# 10221              40     United-States   <=50K       0.708809
# 5275               40     United-States   <=50K       0.377572
# 25311              15     United-States   <=50K       0.029993
# 18738              40     United-States   <=50K       0.762268
# 4111               10     United-States   <=50K       0.617327
# 4072               40     United-States   <=50K       0.213579
# 12008              55     United-States   <=50K       0.459975
# 2303               35     United-States   <=50K       0.836325
# 2304               35     United-States   <=50K       0.693128
# 10557              50           Ecuador    >50K       0.556168
# 1040               40     United-States   <=50K       0.277429
#
# [32562 rows x 16 columns]

# %% [markdown]
# #### 10. Применение функций
# Замените каждое значение в каждом из числовых (type == int) столбцов на среднеквадратичное отклонение по этому столбцу

# %%
# Используем несмещённую оценку (значение по-умолчанию в DataFrame.std(), параметр: ddof=1)
for i in df.select_dtypes('number').columns:
    df[i] = df[i].std()
df
# Out:
#                 age          workclass        fnlwgt      education  \
# 6895   1.776384e-15            Private  4.365642e-11   Some-college
# 14907  1.776384e-15            Private  4.365642e-11           11th
# 7788   1.776384e-15            Private  4.365642e-11           11th
# 12919  1.776384e-15            Private  4.365642e-11           10th
# 7764   1.776384e-15            Private  4.365642e-11           11th
# 26800  1.776384e-15            Private  4.365642e-11           10th
# 26814  1.776384e-15            Private  4.365642e-11            9th
# 23178  1.776384e-15            Private  4.365642e-11           11th
# 21557  1.776384e-15                  ?  4.365642e-11           12th
# 7672   1.776384e-15                  ?  4.365642e-11           11th
# 7653   1.776384e-15            Private  4.365642e-11            9th
# 26874  1.776384e-15        Federal-gov  4.365642e-11           11th
# 22965  1.776384e-15            Private  4.365642e-11           11th
# 26905  1.776384e-15            Private  4.365642e-11            9th
# 31774  1.776384e-15                  ?  4.365642e-11           10th
# 19016  1.776384e-15            Private  4.365642e-11           11th
# 26969  1.776384e-15            Private  4.365642e-11           10th
# 26871  1.776384e-15            Private  4.365642e-11           11th
# 14862  1.776384e-15       Self-emp-inc  4.365642e-11            9th
# 7957   1.776384e-15            Private  4.365642e-11           10th
# 31866  1.776384e-15            Private  4.365642e-11           12th
# 8302   1.776384e-15            Private  4.365642e-11           11th
# 804    1.776384e-15            Private  4.365642e-11           11th
# 26423  1.776384e-15                  ?  4.365642e-11           10th
# 14699  1.776384e-15                  ?  4.365642e-11           11th
# 814    1.776384e-15            Private  4.365642e-11           10th
# 22936  1.776384e-15                  ?  4.365642e-11           10th
# 14731  1.776384e-15            Private  4.365642e-11           11th
# 840    1.776384e-15            Private  4.365642e-11           11th
# 8140   1.776384e-15            Private  4.365642e-11           11th
# ...             ...                ...           ...            ...
# 18845  1.776384e-15            Private  4.365642e-11        Masters
# 6631   1.776384e-15            Private  4.365642e-11           11th
# 6239   1.776384e-15   Self-emp-not-inc  4.365642e-11      Bachelors
# 32368  1.776384e-15          Local-gov  4.365642e-11        7th-8th
# 32278  1.776384e-15            Private  4.365642e-11        HS-grad
# 22231  1.776384e-15            Private  4.365642e-11      Bachelors
# 5373   1.776384e-15          Local-gov  4.365642e-11        Masters
# 28469  1.776384e-15        Federal-gov  4.365642e-11        HS-grad
# 15367  1.776384e-15            Private  4.365642e-11        HS-grad
# 11524  1.776384e-15            Private  4.365642e-11        HS-grad
# 12987  1.776384e-15            Private  4.365642e-11           10th
# 18292  1.776384e-15            Private  4.365642e-11      Bachelors
# 15903  1.776384e-15            Private  4.365642e-11      Bachelors
# 24246  1.776384e-15                  ?  4.365642e-11        1st-4th
# 12463  1.776384e-15                  ?  4.365642e-11   Some-college
# 31032  1.776384e-15            Private  4.365642e-11        HS-grad
# 20623  1.776384e-15            Private  4.365642e-11        Masters
# 5409   1.776384e-15            Private  4.365642e-11        Masters
# 1935   1.776384e-15            Private  4.365642e-11      Bachelors
# 10221  1.776384e-15   Self-emp-not-inc  4.365642e-11   Some-college
# 5275   1.776384e-15            Private  4.365642e-11            9th
# 25311  1.776384e-15                  ?  4.365642e-11        7th-8th
# 18738  1.776384e-15          Local-gov  4.365642e-11        HS-grad
# 4111   1.776384e-15                  ?  4.365642e-11      Bachelors
# 4072   1.776384e-15            Private  4.365642e-11           11th
# 12008  1.776384e-15            Private  4.365642e-11      Bachelors
# 2303   1.776384e-15            Private  4.365642e-11   Some-college
# 2304   1.776384e-15            Private  4.365642e-11   Some-college
# 10557  1.776384e-15            Private  4.365642e-11        HS-grad
# 1040   1.776384e-15            Private  4.365642e-11        HS-grad
#
#        education-num       marital-status          occupation  \
# 6895    4.440960e-16        Never-married        Adm-clerical
# 14907   4.440960e-16        Never-married    Transport-moving
# 7788    4.440960e-16        Never-married       Other-service
# 12919   4.440960e-16        Never-married               Sales
# 7764    4.440960e-16        Never-married       Other-service
# 26800   4.440960e-16        Never-married               Sales
# 26814   4.440960e-16        Never-married   Machine-op-inspct
# 23178   4.440960e-16        Never-married    Transport-moving
# 21557   4.440960e-16        Never-married                   ?
# 7672    4.440960e-16        Never-married                   ?
# 7653    4.440960e-16   Married-civ-spouse       Other-service
# 26874   4.440960e-16        Never-married        Adm-clerical
# 22965   4.440960e-16        Never-married        Adm-clerical
# 26905   4.440960e-16        Never-married               Sales
# 31774   4.440960e-16        Never-married                   ?
# 19016   4.440960e-16        Never-married        Adm-clerical
# 26969   4.440960e-16        Never-married               Sales
# 26871   4.440960e-16        Never-married       Other-service
# 14862   4.440960e-16        Never-married               Sales
# 7957    4.440960e-16        Never-married        Tech-support
# 31866   4.440960e-16        Never-married        Adm-clerical
# 8302    4.440960e-16        Never-married   Handlers-cleaners
# 804     4.440960e-16        Never-married               Sales
# 26423   4.440960e-16        Never-married                   ?
# 14699   4.440960e-16        Never-married                   ?
# 814     4.440960e-16        Never-married     Farming-fishing
# 22936   4.440960e-16        Never-married                   ?
# 14731   4.440960e-16        Never-married       Other-service
# 840     4.440960e-16        Never-married               Sales
# 8140    4.440960e-16        Never-married               Sales
# ...              ...                  ...                 ...
# 18845   4.440960e-16        Never-married     Exec-managerial
# 6631    4.440960e-16   Married-civ-spouse        Craft-repair
# 6239    4.440960e-16   Married-civ-spouse      Prof-specialty
# 32368   4.440960e-16   Married-civ-spouse     Protective-serv
# 32278   4.440960e-16              Widowed        Adm-clerical
# 22231   4.440960e-16        Never-married      Prof-specialty
# 5373    4.440960e-16   Married-civ-spouse     Exec-managerial
# 28469   4.440960e-16   Married-civ-spouse        Craft-repair
# 15367   4.440960e-16              Widowed    Transport-moving
# 11524   4.440960e-16        Never-married       Other-service
# 12987   4.440960e-16   Married-civ-spouse     Exec-managerial
# 18292   4.440960e-16   Married-civ-spouse               Sales
# 15903   4.440960e-16   Married-civ-spouse     Exec-managerial
# 24246   4.440960e-16              Widowed                   ?
# 12463   4.440960e-16        Never-married                   ?
# 31032   4.440960e-16   Married-civ-spouse   Machine-op-inspct
# 20623   4.440960e-16   Married-civ-spouse      Prof-specialty
# 5409    4.440960e-16        Never-married     Exec-managerial
# 1935    4.440960e-16   Married-civ-spouse     Exec-managerial
# 10221   4.440960e-16   Married-civ-spouse     Farming-fishing
# 5275    4.440960e-16        Never-married        Adm-clerical
# 25311   4.440960e-16            Separated                   ?
# 18738   4.440960e-16   Married-civ-spouse       Other-service
# 4111    4.440960e-16              Widowed                   ?
# 4072    4.440960e-16        Never-married   Handlers-cleaners
# 12008   4.440960e-16        Never-married     Exec-managerial
# 2303    4.440960e-16        Never-married       Other-service
# 2304    4.440960e-16        Never-married       Other-service
# 10557   4.440960e-16   Married-civ-spouse        Craft-repair
# 1040    4.440960e-16        Never-married       Other-service
#
#           relationship                 race      sex  capital-gain  \
# 6895         Own-child                White     Male  1.819017e-12
# 14907        Own-child                White     Male  1.819017e-12
# 7788         Own-child                White   Female  1.819017e-12
# 12919        Own-child                Black   Female  1.819017e-12
# 7764         Own-child                Black     Male  1.819017e-12
# 26800   Other-relative                White     Male  1.819017e-12
# 26814        Own-child                White     Male  1.819017e-12
# 23178        Own-child                White   Female  1.819017e-12
# 21557        Own-child                Other   Female  1.819017e-12
# 7672         Own-child                Black   Female  1.819017e-12
# 7653           Husband                White     Male  1.819017e-12
# 26874    Not-in-family                Black   Female  1.819017e-12
# 22965        Own-child                White   Female  1.819017e-12
# 26905   Other-relative                Other   Female  1.819017e-12
# 31774        Own-child                White   Female  1.819017e-12
# 19016   Other-relative                White   Female  1.819017e-12
# 26969        Own-child                White   Female  1.819017e-12
# 26871        Own-child                White   Female  1.819017e-12
# 14862        Own-child                White   Female  1.819017e-12
# 7957         Own-child                White     Male  1.819017e-12
# 31866        Own-child                White   Female  1.819017e-12
# 8302         Own-child                White     Male  1.819017e-12
# 804          Own-child                White   Female  1.819017e-12
# 26423        Own-child                White     Male  1.819017e-12
# 14699        Own-child                White     Male  1.819017e-12
# 814          Own-child                White     Male  1.819017e-12
# 22936        Own-child                White   Female  1.819017e-12
# 14731        Own-child   Amer-Indian-Eskimo   Female  1.819017e-12
# 840          Own-child                White     Male  1.819017e-12
# 8140         Own-child                White   Female  1.819017e-12
# ...                ...                  ...      ...           ...
# 18845        Own-child                White   Female  1.819017e-12
# 6631           Husband                White     Male  1.819017e-12
# 6239           Husband                White     Male  1.819017e-12
# 32368          Husband                White     Male  1.819017e-12
# 32278        Unmarried                White   Female  1.819017e-12
# 22231    Not-in-family   Asian-Pac-Islander     Male  1.819017e-12
# 5373           Husband                White     Male  1.819017e-12
# 28469          Husband                White     Male  1.819017e-12
# 15367        Unmarried                White     Male  1.819017e-12
# 11524        Own-child                White   Female  1.819017e-12
# 12987          Husband                White     Male  1.819017e-12
# 18292          Husband                White     Male  1.819017e-12
# 15903             Wife                White   Female  1.819017e-12
# 24246    Not-in-family                Black   Female  1.819017e-12
# 12463        Own-child   Asian-Pac-Islander     Male  1.819017e-12
# 31032          Husband                White     Male  1.819017e-12
# 20623             Wife                White   Female  1.819017e-12
# 5409     Not-in-family                Black     Male  1.819017e-12
# 1935           Husband                White     Male  1.819017e-12
# 10221          Husband                White     Male  1.819017e-12
# 5275     Not-in-family                White   Female  1.819017e-12
# 25311    Not-in-family                White   Female  1.819017e-12
# 18738          Husband                White     Male  1.819017e-12
# 4111    Other-relative                White   Female  1.819017e-12
# 4072         Own-child                White     Male  1.819017e-12
# 12008    Not-in-family                White     Male  1.819017e-12
# 2303     Not-in-family   Asian-Pac-Islander     Male  1.819017e-12
# 2304     Not-in-family   Asian-Pac-Islander     Male  1.819017e-12
# 10557          Husband                White     Male  1.819017e-12
# 1040     Not-in-family                White   Female  1.819017e-12
#
#        capital-loss  hours-per-week    native-country  salary  random_column
# 6895   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 14907  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 7788   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 12919  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 7764   1.136886e-13    1.776384e-15             Haiti   <=50K   5.551200e-17
# 26800  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 26814  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 23178  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 21557  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 7672   1.136886e-13    1.776384e-15   Trinadad&Tobago   <=50K   5.551200e-17
# 7653   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 26874  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 22965  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 26905  1.136886e-13    1.776384e-15            Mexico   <=50K   5.551200e-17
# 31774  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 19016  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 26969  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 26871  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 14862  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 7957   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 31866  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 8302   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 804    1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 26423  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 14699  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 814    1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 22936  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 14731  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 840    1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 8140   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# ...             ...             ...               ...     ...            ...
# 18845  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 6631   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 6239   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 32368  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 32278  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 22231  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 5373   1.136886e-13    1.776384e-15     United-States    >50K   5.551200e-17
# 28469  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 15367  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 11524  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 12987  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 18292  1.136886e-13    1.776384e-15                 ?   <=50K   5.551200e-17
# 15903  1.136886e-13    1.776384e-15           England    >50K   5.551200e-17
# 24246  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 12463  1.136886e-13    1.776384e-15             South   <=50K   5.551200e-17
# 31032  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 20623  1.136886e-13    1.776384e-15     United-States    >50K   5.551200e-17
# 5409   1.136886e-13    1.776384e-15     United-States    >50K   5.551200e-17
# 1935   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 10221  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 5275   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 25311  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 18738  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 4111   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 4072   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 12008  1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 2303   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 2304   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
# 10557  1.136886e-13    1.776384e-15           Ecuador    >50K   5.551200e-17
# 1040   1.136886e-13    1.776384e-15     United-States   <=50K   5.551200e-17
#
# [32562 rows x 16 columns]

# %% [markdown]
# <center style="background-color: #23B04A; color: white; font-size: 16px"><b>Анализ данных по доходу населения UCI Adult</b></center>

# %% [markdown]
# ### Практические задания:

# %% [markdown]
# #### Обновляем файл adult.data и решаем задания ниже на нём

# %% [markdown]
# Уникальные значения признаков в датафрейме:
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - salary: >50K,<=50K

# %% [markdown]
# #### 11. Каков средний возраст (признак *age*) мужчин?

# %%
np.mean(df[df.sex.apply(lambda x: x.replace(' ', '')) == 'Male'].age)
# Out:
# 39.43354749885268

# %% [markdown]
# **12. Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год? **

# %%
print(df.groupby('salary').age.mean())

# Используем несмещённую оценку (значение по-умолчанию в DataFrame.std(), параметр: ddof=1)
print(df.groupby('salary').age.std())
# Out:
# salary
#  <=50K    36.783738
#  >50K     44.249841
# Name: age, dtype: float64
# salary
#  <=50K    14.020088
#  >50K     10.519028
# Name: age, dtype: float64

# %% [markdown]
# **13. Найдите таким образом максимальный возраст мужчин расы *Amer-Indian-Eskimo*.**

# %%
df[df.race.apply(lambda x: x.replace(' ', '')) == 'Amer-Indian-Eskimo'].age.max()
# Out:
# 82

# %% [markdown]
# **14. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много (*salary* >50k)?**

# %%
max_hours = df['hours-per-week'].max() # Максимальное значение в столбце hours-per-week
print(max_hours)
max_hours_df = df[df['hours-per-week'] == max_hours]
print(len(max_hours_df.index)) # Количество записей в DataFrame со значением max_hours в столбце hours-per-week
# Делим количество записей в каждой группе на общее количество записей со значением max_hours в столбце hours-per-week
print(max_hours_df.groupby('salary').size() / len(max_hours_df) * 100)
# Out:
# 99
# 85
# salary
#  <=50K    70.588235
#  >50K     29.411765
# dtype: float64

# %% [markdown]
# **15. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
df.groupby(['native-country', 'salary'])['hours-per-week'].mean()
# Out:
# native-country               salary
#  ?                            <=50K    40.164760
#                               >50K     45.547945
#  Cambodia                     <=50K    41.416667
#                               >50K     40.000000
#  Canada                       <=50K    37.914634
#                               >50K     45.641026
#  China                        <=50K    37.381818
#                               >50K     38.900000
#  Columbia                     <=50K    38.684211
#                               >50K     50.000000
#  Cuba                         <=50K    37.985714
#                               >50K     42.440000
#  Dominican-Republic           <=50K    42.338235
#                               >50K     47.000000
#  Ecuador                      <=50K    38.041667
#                               >50K     48.750000
#  El-Salvador                  <=50K    36.030928
#                               >50K     45.000000
#  England                      <=50K    40.483333
#                               >50K     44.533333
#  France                       <=50K    41.058824
#                               >50K     50.750000
#  Germany                      <=50K    39.139785
#                               >50K     44.977273
#  Greece                       <=50K    41.809524
#                               >50K     50.625000
#  Guatemala                    <=50K    39.360656
#                               >50K     36.666667
#  Haiti                        <=50K    36.325000
#                               >50K     42.750000
#                                          ...
#  Mexico                       >50K     46.575758
#  Nicaragua                    <=50K    36.093750
#                               >50K     37.500000
#  Outlying-US(Guam-USVI-etc)   <=50K    41.857143
#  Peru                         <=50K    35.068966
#                               >50K     40.000000
#  Philippines                  <=50K    38.065693
#                               >50K     43.032787
#  Poland                       <=50K    38.166667
#                               >50K     39.000000
#  Portugal                     <=50K    41.939394
#                               >50K     41.500000
#  Puerto-Rico                  <=50K    38.470588
#                               >50K     39.416667
#  Scotland                     <=50K    39.444444
#                               >50K     46.666667
#  South                        <=50K    40.156250
#                               >50K     51.437500
#  Taiwan                       <=50K    33.774194
#                               >50K     46.800000
#  Thailand                     <=50K    42.866667
#                               >50K     58.333333
#  Trinadad&Tobago              <=50K    37.058824
#                               >50K     40.000000
#  United-States                <=50K    38.799127
#                               >50K     45.505369
#  Vietnam                      <=50K    37.193548
#                               >50K     39.200000
#  Yugoslavia                   <=50K    41.600000
#                               >50K     49.500000
# Name: hours-per-week, Length: 82, dtype: float64
